# %%
import sys
import os

sys.path.insert(0, os.path.abspath(".."))

from src.data_processing import fetch_stock_safe

df = fetch_stock_safe("AAPL", "2020-01-01", "2023-01-01")

print(df.head())
print(df.columns)
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2 import os
#       4 sys.path.insert(0, os.path.abspath(".."))
# ----> 6 from src.data_processing import fetch_stock
#       8 df = fetch_stock_safe("AAPL", "2020-01-01", "2023-01-01")
#      10 print(df.head())
#
# ImportError: cannot import name 'fetch_stock' from 'src.data_processing' (c:\Users\laksh\Documents\stock_dashboard\src\data_processing.py)
